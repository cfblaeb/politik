# %%
import requests as rq
import pandas as pd
from sqlalchemy import create_engine

# %%
def scrape(table):
    totalcount = int(rq.get('http://oda.ft.dk/api/{}'.format(table), params={"$inlinecount": "allpages"}).json()['odata.count'])
    ccount = 0
    
    while ccount<totalcount:
        r = rq.get('http://oda.ft.dk/api/{}'.format(table), params={"$skip": ccount})
        for row in r.json()['value']:
            yield row

        ccount += 20
        if ccount%10000==0:
            print("{}/{}".format(ccount, totalcount))

# %%
list_of_tables = [
    #"Afstemning",
                  #"Afstemningstype",
                  #"Aktstykke",
                  #"Aktør",
                  #"AktørAktør",
                  #"AktørAktørRolle",
                  #"Aktørtype",
                  #"Almdel",
                  #"Dagsordenspunkt",
                  #"DagsordenspunktDokument",
                  #"DagsordenspunktSag",
                  #"Debat",
                  #"Dokument",
                  #"DokumentAktør",
                  #"DokumentAktørRolle",
    #"Dokumentkategori","Dokumenttype",
    #"Dokumentstatus","Emneord",
    #"EmneordSag","Emneordstype",
    "KolloneBeskrivelse",
    "TabelBeskrivelse","Møde",
    "MødeAktør",
    "Mødestatus","Mødetype",
    "Nyhed",
    "Omtryk","Periode","Sag",
    "SagAktør","SagAktørRolle",
    "SagDokumentRolle","Sagskategori",
    "Sagsstatus",
    "Sagstrin",
    "SagstrinAktør","SagstrinAktørRolle",
    "SagstrinSagstrin",
    "SagstrinDokument",
    "Sagstrinsstatus",
    "SagstrinTale","Sagstrinstype",
    "Sagstype",
    "Stemme"]
con = create_engine('postgresql://politik:polipass@localhost/mydb')

# %%
for tab in list_of_tables:
    print(tab)
    try:
        pd.DataFrame.from_dict(scrape(tab)).to_sql(tab, con, index=False, if_exists='replace')
    except:
        print("some error for {}".format(tab))
# Out:
# Dokumentkategori
# Dokumenttype
# Dokumentstatus
# Emneord
# EmneordDokument
# some error for EmneordDokument
# EmneordSag
# 10000/10691
# Emneordstype
# EUsag
# some error for EUsag
# Forslag
# some error for Forslag
# Fil
# 10000/99026
# 20000/99026
# 30000/99026
# some error for Fil
# KolloneBeskrivelse
# TabelBeskrivelse
# Møde
# MødeAktør
# Mødestatus
# Mødetype
# Nyhed
# some error for Nyhed
# Omtryk
# Periode
# Sag
# SagAktør
# 10000/24918
# 20000/24918
# SagAktørRolle
# SagDokument
# 10000/99449
# 20000/99449
# 30000/99449
# 40000/99449
# 50000/99449
# some error for SagDokument
# SagDokumentRolle
# Sagskategori
# Sagsstatus
# Sagstrin
# 10000/22712
# 20000/22712
# SagstrinAktør
# SagstrinAktørRolle
# SagstrinSagstrin
# SagstrinDokument
# some error for SagstrinDokument
# Sagstrinsstatus
# SagstrinTale
# some error for SagstrinTale
# Sagstrinstype
# Sagstype
# Stemme
# 10000/193320
# 20000/193320
# 30000/193320
# 40000/193320
# 50000/193320
# 60000/193320
# 70000/193320
# 80000/193320
# 90000/193320
# 100000/193320
# 110000/193320
# 120000/193320
# 130000/193320
# 140000/193320
# 150000/193320
# 160000/193320
# 170000/193320
# 180000/193320
# 190000/193320
